# %% [markdown]
# # Method 1:  Determine k for spring 1 and 2

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

#define plotting and linear least squares fitting as functions

#goodness of fit parameter
def LLSFD2(x,y,dy,b,m):
    N = sum(((y-b-m*x)/dy)**2)
    return N
                      
def Delta(x, dy):
    D = (sum(1/dy**2))*(sum(x**2/dy**2))-(sum(x/dy**2))**2
    return D


def plotfit(x,y,dy,title,xlabel,ylabel,slopeunit):
    b,m=np.polynomial.polynomial.polyfit(x,y,1,w=dy)
    fit = b+m*x
    N = LLSFD2(x,y,dy,b,m)    
    D=Delta(x, dy)
    dm = math.sqrt(1/D*sum(1/dy**2)) #error in slope
    db = math.sqrt(1/D*sum(x**2/dy**2)) #error in intercept
    plt.scatter(x, y, color='red', marker='o')
    #Plot least squares fit line
    plt.plot(x, fit, color='green', linestyle='--')

    #Plot y error bars - do not need to modify
    plt.errorbar(x, y, yerr=dy, xerr=None, fmt="none")

    #Write x and y axes labels, title.  Modify these!
    plt.xlabel(mass) #x-axis label
    plt.ylabel(force) #y-axis label
    plt.title(hooks) #plot title
    plt.show()
    
    print (f"Slope = {m:.2f} {slopeunit}")
    print (f"Error in slope = {dm:.2f} {slopeunit}")
    print (f"Goodness of fit = {N:.2f}")

# %%
import physplot as phys
import numpy as np

#spring 1
m1 = np.array([53,67,100,199,221,246])/1000
x1 = np.array([19.1,24.2,34.8,66.9,74.3,82.4])/100
errm = np.array([1,1,1,1,1,1])/1000

#call the plotfit function from the physplot.py code
#You can open that code to see how it works
#This is what the plotfit function looks like.  Pass
#in the parameters in the correct order
#plotfit(x,y,dy,title,xlabel,ylabel,slopeunit)

phys.plotfit(x1,m1*9.8,errm*9.8,'Small k spring','x(m)','F(N)','N/m')
# Out:
# Slope = 3.00 N/m
# Error in slope = 0.02 N/m
# Goodness of fit = 1.62

# %%
import physplot as phys
import numpy as np

#spring 1
m1 = np.array([60,85,100,145,235,295])/1000
x1 = np.array([7,8.8,10.1,13.9,21.2,26])/100
errm = np.array([1,1,1,1,1,1])/1000

#call the plotfit function from the physplot.py code
#You can open that code to see how it works
#This is what the plotfit function looks like.  Pass
#in the parameters in the correct order
#plotfit(x,y,dy,title,xlabel,ylabel,slopeunit)

phys.plotfit(x1,m1*9.8,errm*9.8,'big k spring','x(m)','F(N)','N/m')
# Out:
# Slope = 12.03 N/m
# Error in slope = 0.06 N/m
# Goodness of fit = 6.27

# %%
import physplot as phys
import numpy as np

#spring 1
m1 = np.array([55,80,115,220,250,300])/1000
x1 = np.array([4.41,5.17,6.14,7.09,8.40,9.73])
errm = np.array([1,1,1,1,1,1])/1000

#call the plotfit function from the physplot.py code
#You can open that code to see how it works
#This is what the plotfit function looks like.  Pass
#in the parameters in the correct order
#plotfit(x,y,dy,title,xlabel,ylabel,slopeunit)

phys.plotfit(x1,m1*9.8,errm*9.8,'big k spring','x(m)','T(sec)','N/m')
# Out:
# Slope = 0.48 N/m
# Error in slope = 0.00 N/m
# Goodness of fit = 2080.33

# %%
import physplot as phys
import numpy as np

#spring 1
m1 = np.array([50,90,150,160,240,300])/1000
x1 = np.array([7.61,10.31,13.41,13.83,16.57,20])
errm = np.array([1,1,1,1,1,1])/1000

#call the plotfit function from the physplot.py code
#You can open that code to see how it works
#This is what the plotfit function looks like.  Pass
#in the parameters in the correct order
#plotfit(x,y,dy,title,xlabel,ylabel,slopeunit)

phys.plotfit(x1,m1*9.8,errm*9.8,'Small k spring','x(m)','T(sec)','N/m')
# Out:
# Slope = 0.21 N/m
# Error in slope = 0.00 N/m
# Goodness of fit = 527.67
